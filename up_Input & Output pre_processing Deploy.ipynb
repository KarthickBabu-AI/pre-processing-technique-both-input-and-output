# %%
import pickle

# %%
input_model=pickle.load(open('input1_processing.sav','rb'))

# %%
preinput=input_model.transform([[100,200,300,1,1]])
preinput
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[ -1.26491106,  55.65608682, 112.5770847 ,   1.        ,
#           1.        ]])

# %%
loaded_model=pickle.load(open('finalized_Multimodel.sav','rb'))
result=loaded_model.predict(preinput)
result
# Out:
# array([[55.65608682]])

# %%
output_model1=pickle.load(open('output1_processing.sav','rb'))
preoutput=output_model1.inverse_transform(result)
preoutput
# Out:
# array([[390.]])
